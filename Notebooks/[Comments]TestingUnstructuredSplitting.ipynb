# %%
from itext2kg.documents_distiller import DocumentsDistiller, Article
import asyncio
from itext2kg import iText2KG_Star
from itext2kg.logging_config import setup_logging, get_logger
from itext2kg import itext2kg_star
from langchain_ollama import ChatOllama, OllamaEmbeddings
import time
from datetime import datetime

# %%
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Load all .txt files from a directory
loader = DirectoryLoader(
    "./data/unstructured/",
    glob="*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding': 'utf-8'}
)
documents = loader.load()

# Split if needed
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)
pages = text_splitter.split_documents(documents)

# %%
# Create models for distillation

# %%
from typing import List, Optional
from pydantic import BaseModel, Field, field_validator
class ContentSource(BaseModel):
    name: str = Field(description="Name of the author/speaker/presenter")
    role: Optional[str] = Field(description="Role or position")
    affiliation: Optional[str] = Field(description="Organization or company affiliation")
class Content(BaseModel):
    title: str = Field(description="Title of the content (article/video)")
    sources: List[ContentSource] = Field(description="Authors/speakers involved")
    summary: str = Field(description="Brief summary of the content")
    key_concepts: List[str] = Field(description="Main concepts or topics covered")
    insights: str = Field(description="Key insights and findings")
    challenges: str = Field(description="Challenges or limitations discussed")
    solutions: str = Field(description="Proposed solutions or approaches")
    practical_applications: str = Field(description="Practical applications or implementations mentioned")

# %%
# Set up connections using langchain

# %%
llm = ChatOllama(
    model="llama3.2:1b",
    temperature=0,
)

# %%
llm_text = ChatOllama(
    model="gemma2:2b",
    temperature=0,
)
embeddings = OllamaEmbeddings(
    model="nomic-embed-text:latest",
)

# %%
IE_query='''# DIRECTIVES :
            - Act like an experienced information extractor.
            - You have a YouTube transcript about Waterfall (preplanned) software development.
            - Extract key concepts, methodologies, best practices, and insights discussed.
            - If you do not find the right information, keep its place empty.
            - Focus on practical advice and real-world applications.''',

# %%
len(pages)
# Out:
# 417

# %%
semantic_blocks=[]

# %%
# Split into blocks

# %%
pages_section=pages[0:9]
facts_0 = await document_distiller.distill(documents=[page.page_content.replace("{", '[').replace("}", "]") for page in pages_section], IE_query=IE_query, output_data_structure=Article)
semantic_blocks = [f"{key} - {value}".replace("{", "[").replace("}", "]")
                     for key, value in facts_0.model_dump().items()
                     if value != [] and value != "" and value is not None]

# %%
semantic_blocks
# Out:
# ['title - Business Case Initiation Tools Project Initiation in Scrum/Agile Software Development # DIRECTIVES : Act like an experienced information extractor. Extract key concepts, methodologies, best practices, and insights discussed. Extracted Key Concepts and Methodologies from the Project Charter Organizational Breakdown Structure (OBS) and Resource Breakdown Structure (RBS): Key Concepts and Methodologies # DIRECTIVES : Act like an experienced information extractor. # DIRECTIVES : \n            - Act like an experienced information extractor.\n            - You have a YouTube transcript about Scrum/Agile software development.\n            - Extract key concepts, methodologies, best practices, and insights discussed.\n            - If you do not find the right information, keep its place empty.\n            - Focus on practical advice and real-world applications. Stakeholder Matrix/Map Insights Salience Chart for Stakeholders in Scrum/Agile Software Development',
#  "authors - [['name': 'Experienced Information Extractor', 'affiliation': 'YouTube Transcript'], ['name': 'Samantha', 'affiliation': ''], ['name': 'Samantha', 'affiliation': 'Project Manager'], ['name': 'Pet Sitter Business Plan', 'affiliation': 'Unknown'], ['name': 'Information Extractor', 'affiliation': 'Experienced Information Extractor'], ['name': 'Information Extractor', 'affiliation': 'AI Assistant'], ['name': 'YouTube transcript', 'affiliation': 'Unknown'], ['name': 'John Doe', 'affiliation': 'Project Manager'], ['name': 'John Doe', 'affiliation': 'Information Extractor']]",
#  "abstract - In this context, we will be using the following project management tools to initiate our project. The first two tools are: 1. Business Case Initiation Tool In this context, the project initiation tools are being discussed as part of a feasibility study for a new business case. The goal is to determine if starting the project is worthwhile and whether the proposed solution addresses the current issue or problem. A summary of the key points will be provided, followed by solutions and a recommendation. The project charter outlines the high-level goals, scope, and deliverables of the pet buddy mobile app. It serves as a foundation for the development team to work towards and ensures that all stakeholders are aligned with the project's objectives. In this YouTube transcript, the authors discuss the importance of using OBS and RBS in Scrum/Agile software development. They highlight key concepts such as stakeholder management, organizational charts, and resource allocation. In this context, we're evaluating our project's impact on Samantha, the business owner and project sponsor. We rate their influence as high (10) and impact as high (10). However, her level of influence is extremely high due to her control over resources and funding. This means that if we want to collaborate with Samantha, we need to prioritize communication and ensure she's informed about our project's progress. A salience chart is a visual tool used to identify and prioritize stakeholders' needs, power, legitimacy, and urgency. It's particularly useful for Agile software development projects.",
#  'key_findings - The business case initiation tool is used to define and document the project\'s objectives, scope, and stakeholders. It helps to identify the key issues and opportunities that need to be addressed during the project. [...] 1. The project initiation tools are being considered as part of a feasibility study for a new business case. 2. The goal is to determine if starting the project is worthwhile and whether the proposed solution addresses the current issue or problem. 3. A summary of the key points will be provided, followed by solutions and a recommendation. Scrum/Agile software development principles, methodologies, best practices, and insights discussed in the transcript. project charter [...] ["Scrum/Agile software development", "Resource Breakdown Structure (RBS)"] [Impact: High, Influence: Extremely High]\n\nSamantha (Business Owner/Project Sponsor):\n- High Impact\n- High Influence ["Stakeholders", "Scrum/Agile software development", "Salience chart"]',
#  "limitation_of_sota - Limited to defining and documenting the project's objectives, scope, and stakeholders The limitation of Sota (Scrum/Agile Software Development) is that it requires a clear understanding of the project's goals, scope, and stakeholders to initiate the project effectively. No specific limitations mentioned in the transcript. The project charter is an abstract document that outlines the high-level goals and scope of the pet buddy mobile app. It provides a foundation for the development team to work towards and ensures that all stakeholders are aligned with the project's objectives. None None The salience chart can be used to monitor stakeholders' needs over time, but it may not provide a comprehensive view of their power and legitimacy.",
#  "proposed_solution - The business case initiation tool provides a structured approach to identifying and prioritizing the project's requirements. It helps to ensure that all stakeholders are aligned and that the project is focused on delivering value to customers. A proposed solution for initiating the project would be to create a project charter with the business owner and project manager. This would provide a clear understanding of the project's objectives and ensure that everyone is aligned on the project's direction. The project charter is created with key concepts, methodologies, best practices, and insights discussed. The project manager and sponsor sign off on the project, funding, and people needed to initiate the project. The project charter proposes a solution to develop a pet buddy mobile app, which is a key aspect of the pet sitter business plan. It outlines the high-level goals, scope, and deliverables of the project, ensuring that all stakeholders are aligned with the objectives. Use OBS to identify stakeholders and form a project team, then use RBS for resource allocation. 1. Create a Resource Breakdown Structure (RBS) for the pet buddy mobile app project. Create a stakeholder register for PMP exam preparation and update it regularly to track new stakeholders, their roles, responsibilities, influence, and impact. This will enable easy identification of stakeholders during the exam and provide valuable insights into project management best practices. Maintain communication with Samantha to ensure she's informed about our project's progress. If necessary, collaborate on a high-level stakeholder map or matrix to visualize the impact and influence of various stakeholders. To create a salience chart for stakeholders in Scrum/Agile software development, we need to identify key concepts, methodologies, best practices, and insights discussed in the YouTube transcript. We can use a 3D chart or a Ven diagram to visualize this information.",
#  'paper_limitations - Limited to defining and documenting the project\'s objectives, scope, and stakeholders. [...] 1. The paper limitation is that it does not provide any specific information about the project initiation tools or methodologies used in Scrum/Agile software development. No specific paper limitations mentioned in the transcript. The paper limitations section states that the project charter is an abstract document that provides a foundation for the development team to work towards. It ensures that all stakeholders are aligned with the project\'s objectives and provides a clear understanding of the project scope. [...] ["Capturing all people involved in the project", "Organizing stakeholders and team members"], None [Directives: Act like an experienced information extractor.\n- You have a YouTube transcript about Scrum/Agile software development.\n- Extract key concepts, methodologies, best practices, and insights discussed.\n- If you do not find the right information, keep its place empty.\n- Focus on practical advice and real-world applications.] The transcript may not provide explicit information about stakeholder engagement, power, legitimacy, and urgency. Therefore, we need to focus on practical advice and real-world applications to extract relevant insights.']

# %%
# Test to see if just copying it would result in a useable object

# %%
sb = ['title - Business Case Initiation Tools Project Initiation in Scrum/Agile Software Development # DIRECTIVES : Act like an experienced information extractor. Extract key concepts, methodologies, best practices, and insights discussed. Extracted Key Concepts and Methodologies from the Project Charter Organizational Breakdown Structure (OBS) and Resource Breakdown Structure (RBS): Key Concepts and Methodologies # DIRECTIVES : Act like an experienced information extractor. # DIRECTIVES : \n            - Act like an experienced information extractor.\n            - You have a YouTube transcript about Scrum/Agile software development.\n            - Extract key concepts, methodologies, best practices, and insights discussed.\n            - If you do not find the right information, keep its place empty.\n            - Focus on practical advice and real-world applications. Stakeholder Matrix/Map Insights Salience Chart for Stakeholders in Scrum/Agile Software Development',
 "authors - [['name': 'Experienced Information Extractor', 'affiliation': 'YouTube Transcript'], ['name': 'Samantha', 'affiliation': ''], ['name': 'Samantha', 'affiliation': 'Project Manager'], ['name': 'Pet Sitter Business Plan', 'affiliation': 'Unknown'], ['name': 'Information Extractor', 'affiliation': 'Experienced Information Extractor'], ['name': 'Information Extractor', 'affiliation': 'AI Assistant'], ['name': 'YouTube transcript', 'affiliation': 'Unknown'], ['name': 'John Doe', 'affiliation': 'Project Manager'], ['name': 'John Doe', 'affiliation': 'Information Extractor']]",
 "abstract - In this context, we will be using the following project management tools to initiate our project. The first two tools are: 1. Business Case Initiation Tool In this context, the project initiation tools are being discussed as part of a feasibility study for a new business case. The goal is to determine if starting the project is worthwhile and whether the proposed solution addresses the current issue or problem. A summary of the key points will be provided, followed by solutions and a recommendation. The project charter outlines the high-level goals, scope, and deliverables of the pet buddy mobile app. It serves as a foundation for the development team to work towards and ensures that all stakeholders are aligned with the project's objectives. In this YouTube transcript, the authors discuss the importance of using OBS and RBS in Scrum/Agile software development. They highlight key concepts such as stakeholder management, organizational charts, and resource allocation. In this context, we're evaluating our project's impact on Samantha, the business owner and project sponsor. We rate their influence as high (10) and impact as high (10). However, her level of influence is extremely high due to her control over resources and funding. This means that if we want to collaborate with Samantha, we need to prioritize communication and ensure she's informed about our project's progress. A salience chart is a visual tool used to identify and prioritize stakeholders' needs, power, legitimacy, and urgency. It's particularly useful for Agile software development projects.",
 'key_findings - The business case initiation tool is used to define and document the project\'s objectives, scope, and stakeholders. It helps to identify the key issues and opportunities that need to be addressed during the project. [...] 1. The project initiation tools are being considered as part of a feasibility study for a new business case. 2. The goal is to determine if starting the project is worthwhile and whether the proposed solution addresses the current issue or problem. 3. A summary of the key points will be provided, followed by solutions and a recommendation. Scrum/Agile software development principles, methodologies, best practices, and insights discussed in the transcript. project charter [...] ["Scrum/Agile software development", "Resource Breakdown Structure (RBS)"] [Impact: High, Influence: Extremely High]\n\nSamantha (Business Owner/Project Sponsor):\n- High Impact\n- High Influence ["Stakeholders", "Scrum/Agile software development", "Salience chart"]',
 "limitation_of_sota - Limited to defining and documenting the project's objectives, scope, and stakeholders The limitation of Sota (Scrum/Agile Software Development) is that it requires a clear understanding of the project's goals, scope, and stakeholders to initiate the project effectively. No specific limitations mentioned in the transcript. The project charter is an abstract document that outlines the high-level goals and scope of the pet buddy mobile app. It provides a foundation for the development team to work towards and ensures that all stakeholders are aligned with the project's objectives. None None The salience chart can be used to monitor stakeholders' needs over time, but it may not provide a comprehensive view of their power and legitimacy.",
 "proposed_solution - The business case initiation tool provides a structured approach to identifying and prioritizing the project's requirements. It helps to ensure that all stakeholders are aligned and that the project is focused on delivering value to customers. A proposed solution for initiating the project would be to create a project charter with the business owner and project manager. This would provide a clear understanding of the project's objectives and ensure that everyone is aligned on the project's direction. The project charter is created with key concepts, methodologies, best practices, and insights discussed. The project manager and sponsor sign off on the project, funding, and people needed to initiate the project. The project charter proposes a solution to develop a pet buddy mobile app, which is a key aspect of the pet sitter business plan. It outlines the high-level goals, scope, and deliverables of the project, ensuring that all stakeholders are aligned with the objectives. Use OBS to identify stakeholders and form a project team, then use RBS for resource allocation. 1. Create a Resource Breakdown Structure (RBS) for the pet buddy mobile app project. Create a stakeholder register for PMP exam preparation and update it regularly to track new stakeholders, their roles, responsibilities, influence, and impact. This will enable easy identification of stakeholders during the exam and provide valuable insights into project management best practices. Maintain communication with Samantha to ensure she's informed about our project's progress. If necessary, collaborate on a high-level stakeholder map or matrix to visualize the impact and influence of various stakeholders. To create a salience chart for stakeholders in Scrum/Agile software development, we need to identify key concepts, methodologies, best practices, and insights discussed in the YouTube transcript. We can use a 3D chart or a Ven diagram to visualize this information.",
 'paper_limitations - Limited to defining and documenting the project\'s objectives, scope, and stakeholders. [...] 1. The paper limitation is that it does not provide any specific information about the project initiation tools or methodologies used in Scrum/Agile software development. No specific paper limitations mentioned in the transcript. The paper limitations section states that the project charter is an abstract document that provides a foundation for the development team to work towards. It ensures that all stakeholders are aligned with the project\'s objectives and provides a clear understanding of the project scope. [...] ["Capturing all people involved in the project", "Organizing stakeholders and team members"], None [Directives: Act like an experienced information extractor.\n- You have a YouTube transcript about Scrum/Agile software development.\n- Extract key concepts, methodologies, best practices, and insights discussed.\n- If you do not find the right information, keep its place empty.\n- Focus on practical advice and real-world applications.] The transcript may not provide explicit information about stakeholder engagement, power, legitimacy, and urgency. Therefore, we need to focus on practical advice and real-world applications to extract relevant insights.']

# %%
sb
# Out:
# ['title - Business Case Initiation Tools Project Initiation in Scrum/Agile Software Development # DIRECTIVES : Act like an experienced information extractor. Extract key concepts, methodologies, best practices, and insights discussed. Extracted Key Concepts and Methodologies from the Project Charter Organizational Breakdown Structure (OBS) and Resource Breakdown Structure (RBS): Key Concepts and Methodologies # DIRECTIVES : Act like an experienced information extractor. # DIRECTIVES : \n            - Act like an experienced information extractor.\n            - You have a YouTube transcript about Scrum/Agile software development.\n            - Extract key concepts, methodologies, best practices, and insights discussed.\n            - If you do not find the right information, keep its place empty.\n            - Focus on practical advice and real-world applications. Stakeholder Matrix/Map Insights Salience Chart for Stakeholders in Scrum/Agile Software Development',
#  "authors - [['name': 'Experienced Information Extractor', 'affiliation': 'YouTube Transcript'], ['name': 'Samantha', 'affiliation': ''], ['name': 'Samantha', 'affiliation': 'Project Manager'], ['name': 'Pet Sitter Business Plan', 'affiliation': 'Unknown'], ['name': 'Information Extractor', 'affiliation': 'Experienced Information Extractor'], ['name': 'Information Extractor', 'affiliation': 'AI Assistant'], ['name': 'YouTube transcript', 'affiliation': 'Unknown'], ['name': 'John Doe', 'affiliation': 'Project Manager'], ['name': 'John Doe', 'affiliation': 'Information Extractor']]",
#  "abstract - In this context, we will be using the following project management tools to initiate our project. The first two tools are: 1. Business Case Initiation Tool In this context, the project initiation tools are being discussed as part of a feasibility study for a new business case. The goal is to determine if starting the project is worthwhile and whether the proposed solution addresses the current issue or problem. A summary of the key points will be provided, followed by solutions and a recommendation. The project charter outlines the high-level goals, scope, and deliverables of the pet buddy mobile app. It serves as a foundation for the development team to work towards and ensures that all stakeholders are aligned with the project's objectives. In this YouTube transcript, the authors discuss the importance of using OBS and RBS in Scrum/Agile software development. They highlight key concepts such as stakeholder management, organizational charts, and resource allocation. In this context, we're evaluating our project's impact on Samantha, the business owner and project sponsor. We rate their influence as high (10) and impact as high (10). However, her level of influence is extremely high due to her control over resources and funding. This means that if we want to collaborate with Samantha, we need to prioritize communication and ensure she's informed about our project's progress. A salience chart is a visual tool used to identify and prioritize stakeholders' needs, power, legitimacy, and urgency. It's particularly useful for Agile software development projects.",
#  'key_findings - The business case initiation tool is used to define and document the project\'s objectives, scope, and stakeholders. It helps to identify the key issues and opportunities that need to be addressed during the project. [...] 1. The project initiation tools are being considered as part of a feasibility study for a new business case. 2. The goal is to determine if starting the project is worthwhile and whether the proposed solution addresses the current issue or problem. 3. A summary of the key points will be provided, followed by solutions and a recommendation. Scrum/Agile software development principles, methodologies, best practices, and insights discussed in the transcript. project charter [...] ["Scrum/Agile software development", "Resource Breakdown Structure (RBS)"] [Impact: High, Influence: Extremely High]\n\nSamantha (Business Owner/Project Sponsor):\n- High Impact\n- High Influence ["Stakeholders", "Scrum/Agile software development", "Salience chart"]',
#  "limitation_of_sota - Limited to defining and documenting the project's objectives, scope, and stakeholders The limitation of Sota (Scrum/Agile Software Development) is that it requires a clear understanding of the project's goals, scope, and stakeholders to initiate the project effectively. No specific limitations mentioned in the transcript. The project charter is an abstract document that outlines the high-level goals and scope of the pet buddy mobile app. It provides a foundation for the development team to work towards and ensures that all stakeholders are aligned with the project's objectives. None None The salience chart can be used to monitor stakeholders' needs over time, but it may not provide a comprehensive view of their power and legitimacy.",
#  "proposed_solution - The business case initiation tool provides a structured approach to identifying and prioritizing the project's requirements. It helps to ensure that all stakeholders are aligned and that the project is focused on delivering value to customers. A proposed solution for initiating the project would be to create a project charter with the business owner and project manager. This would provide a clear understanding of the project's objectives and ensure that everyone is aligned on the project's direction. The project charter is created with key concepts, methodologies, best practices, and insights discussed. The project manager and sponsor sign off on the project, funding, and people needed to initiate the project. The project charter proposes a solution to develop a pet buddy mobile app, which is a key aspect of the pet sitter business plan. It outlines the high-level goals, scope, and deliverables of the project, ensuring that all stakeholders are aligned with the objectives. Use OBS to identify stakeholders and form a project team, then use RBS for resource allocation. 1. Create a Resource Breakdown Structure (RBS) for the pet buddy mobile app project. Create a stakeholder register for PMP exam preparation and update it regularly to track new stakeholders, their roles, responsibilities, influence, and impact. This will enable easy identification of stakeholders during the exam and provide valuable insights into project management best practices. Maintain communication with Samantha to ensure she's informed about our project's progress. If necessary, collaborate on a high-level stakeholder map or matrix to visualize the impact and influence of various stakeholders. To create a salience chart for stakeholders in Scrum/Agile software development, we need to identify key concepts, methodologies, best practices, and insights discussed in the YouTube transcript. We can use a 3D chart or a Ven diagram to visualize this information.",
#  'paper_limitations - Limited to defining and documenting the project\'s objectives, scope, and stakeholders. [...] 1. The paper limitation is that it does not provide any specific information about the project initiation tools or methodologies used in Scrum/Agile software development. No specific paper limitations mentioned in the transcript. The paper limitations section states that the project charter is an abstract document that provides a foundation for the development team to work towards. It ensures that all stakeholders are aligned with the project\'s objectives and provides a clear understanding of the project scope. [...] ["Capturing all people involved in the project", "Organizing stakeholders and team members"], None [Directives: Act like an experienced information extractor.\n- You have a YouTube transcript about Scrum/Agile software development.\n- Extract key concepts, methodologies, best practices, and insights discussed.\n- If you do not find the right information, keep its place empty.\n- Focus on practical advice and real-world applications.] The transcript may not provide explicit information about stakeholder engagement, power, legitimacy, and urgency. Therefore, we need to focus on practical advice and real-world applications to extract relevant insights.']

# %%
itext2kg_star = iText2KG_Star(llm_model=llm_text, embeddings_model=embeddings)

# %%
# Construct graph

# %%
kg = await itext2kg_star.build_graph(
    sections=sb,
    ent_threshold=0.8,      # Higher threshold for more distinct entities
    rel_threshold=0.7,      # Threshold for relationship merging
)
# Out:
# [2025-08-22 14:08:19] [    INFO] [itext2kg.itext2kg.itext2kg_star] ------- Extracting Relations and Deriving Entities from Document 1
# [2025-08-22 14:08:59] [    INFO] [itext2kg.itext2kg.itext2kg_star] ------- Extracting Relations and Deriving Entities from Document 2
# [2025-08-22 14:09:38] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [youtube transcript:authors] --merged--> [youtube transcript:YouTube_Transcript]
# [2025-08-22 14:09:38] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [youtube transcript:affiliation] --merged--> [youtube transcript:YouTube_Transcript]
# [2025-08-22 14:09:38] [    INFO] [itext2kg.itext2kg.itext2kg_star] ------- Extracting Relations and Deriving Entities from Document 3
# [2025-08-22 14:10:14] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [samantha:Project_Impact_Evaluation] --merged--> [samantha:authors]
# [2025-08-22 14:10:14] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [business case initiation tool:Project_Initiation_Tools] --merged--> [business case initiation tools:Business_Case_Initiation_Tools]
# [2025-08-22 14:10:14] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [pet buddy mobile app project charter:Project_Charter] --merged--> [project charter:Project_Charter]
# [2025-08-22 14:10:14] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Relationship__YouTube_Transcript_to_Scrum_Agile_Software_Development] --merged --> [Relationship_between_Scrum_Agile_Software_Development_and_YouTube_Transcript]
# [2025-08-22 14:10:14] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Relationship__Business_Case_Initiation_Tool_to_Project_Charter] --merged --> [Relationship_between_Project_Initiation_and_Business_Case_Initiation_Tools]
# [2025-08-22 14:10:14] [    INFO] [itext2kg.itext2kg.itext2kg_star] ------- Extracting Relations and Deriving Entities from Document 4
# [2025-08-22 14:11:15] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [business case initiation tool:Business_Case_Initiation_Tool] --merged--> [business case initiation tools:Business_Case_Initiation_Tools]
# [2025-08-22 14:11:15] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [resource breakdown structure:Resource_Breakdown_Structure__RBS_] --merged--> [resource breakdown structure (rbs):Resource_Breakdown_Structure__RBS_]
# [2025-08-22 14:11:15] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [project initiation tools:Project_Initiation_Tools] --merged--> [project initiation:Project_Initiation]
# [2025-08-22 14:11:15] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [scrum agile software development:Scrum_Agile_Software_Development] --merged--> [scrum/agile software development:Scrum_Agile_Software_Development]
# [2025-08-22 14:11:15] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [The_business_case_initiation_tool_is_used_to_define_and_document_the_project_s_objectives__scope__and_stakeholders_] --merged --> [Relationship_between_Project_Initiation_and_Business_Case_Initiation_Tools]
# [2025-08-22 14:11:15] [    INFO] [itext2kg.itext2kg.itext2kg_star] ------- Extracting Relations and Deriving Entities from Document 5
# [2025-08-22 14:11:41] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [salient chart:Salience_Chart] --merged--> [insights salience chart for stakeholders:Insights_Salience_Chart_for_Stakeholders]
# [2025-08-22 14:11:41] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Ensures_Alignment_with_Project_Objectives] --merged --> [Defines_and_documents_project_objectives__scope__and_stakeholders_]
# [2025-08-22 14:11:41] [    INFO] [itext2kg.itext2kg.itext2kg_star] ------- Extracting Relations and Deriving Entities from Document 6
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [business case initiation tool:Business_Case_Initiation_Tool] --merged--> [business case initiation tools:Business_Case_Initiation_Tools]
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [project initiation sign off:Project_Initiation_Sign_Off] --merged--> [project initiation:Project_Initiation]
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [pet buddy mobile app:Pet_Buddy_Mobile_App] --merged--> [pet buddy mobile app project:Project]
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [stakeholder map matrix:Stakeholder_Map_Matrix] --merged--> [stakeholder matrix/map:Stakeholder_Matrix_Map]
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [project team:Project_Team] --merged--> [development team:Development_Team]
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Maintain_communication_with_Samantha_to_ensure_she_s_informed_about_our_project_s_progress_] --merged --> [Relationship__Project_Impact_Evaluation_to_Samantha_s_Communication]
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Created_with_key_concepts__methodologies__best_practices__and_insights_discussed_] --merged --> [Principles__methodologies__best_practices__and_insights_discussed_in_the_transcript_]
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Enables_easy_identification_of_stakeholders_during_the_exam_and_provides_valuable_insights_into_project_management_best_practices_] --merged --> [Helps_to_identify_key_issues_and_opportunities_that_need_to_be_addressed_during_the_project_]
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Ensures_that_all_stakeholders_are_aligned_and_the_project_is_focused_on_delivering_value_to_customers_] --merged --> [Defines_and_documents_project_objectives__scope__and_stakeholders_]
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [To_create_a_salience_chart_for_stakeholders_in_Scrum_Agile_software_development__we_need_to_identify_key_concepts__methodologies__best_practices__and_insights_discussed_] --merged --> [Relationship_between_Scrum_Agile_Software_Development_and_Insights_Salience_Chart_for_Stakeholders]
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Outlines_the_high_level_goals__scope__and_deliverables_of_the_project_] --merged --> [Defines_and_documents_project_objectives__scope__and_stakeholders_]
# [2025-08-22 14:13:01] [    INFO] [itext2kg.itext2kg.itext2kg_star] ------- Extracting Relations and Deriving Entities from Document 7
# [2025-08-22 14:13:39] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [stakeholders:stakeholders] --merged--> [stakeholders:Stakeholders]
# [2025-08-22 14:13:39] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [project charter:project_charter] --merged--> [project charter:Project_Charter]
# [2025-08-22 14:13:39] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [foundation for development team:foundation_for_development_team] --merged--> [development team:Development_Team]
# [2025-08-22 14:13:39] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [project scope:project_scope] --merged--> [project scope:Project_Scope]
# [2025-08-22 14:13:39] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Entity was matched --- [clear understanding of project scope:clear_understanding_of_project_scope] --merged--> [project scope:Project_Scope]
# [2025-08-22 14:13:39] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Defines_and_documents_project_objectives] --merged --> [Defines_and_documents_project_objectives__scope__and_stakeholders_]
# [2025-08-22 14:13:39] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Ensures_all_stakeholders_are_aligned_with_the_project_s_objectives] --merged --> [Provides_a_clear_understanding_of_the_project_s_objectives_and_ensures_that_everyone_is_aligned_on_the_project_s_direction_]
# [2025-08-22 14:13:39] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Provides_a_clear_understanding_of_the_project_scope] --merged --> [Provides_a_clear_understanding_of_the_project_s_objectives_and_ensures_that_everyone_is_aligned_on_the_project_s_direction_]
# [2025-08-22 14:13:39] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Defines_and_documents_project_scope] --merged --> [Defines_and_documents_project_objectives__scope__and_stakeholders_]
# [2025-08-22 14:13:39] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Provides_a_foundation_for_the_development_team_to_work_towards] --merged --> [Provides_Foundation_for_Development]
# [2025-08-22 14:13:39] [    INFO] [itext2kg.itext2kg.graph_matching.matcher] Relation was matched --- [Defines_and_documents_project_stakeholders] --merged --> [Defines_and_documents_project_objectives__scope__and_stakeholders_]

# %%
pages_section=pages[0:99]
facts_0 = await document_distiller.distill(documents=[page.page_content.replace("{", '[').replace("}", "]") for page in pages_section], IE_query=IE_query, output_data_structure=Article)
semantic_blocks = [f"{key} - {value}".replace("{", "[").replace("}", "]")
                     for key, value in facts_0.model_dump().items()
                     if value != [] and value != "" and value is not None]
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[169], line 2
#       1 pages_section=pages[0:99]
# ----> 2 facts_0 = await document_distiller.distill(documents=[page.page_content.replace("{", '[').replace("}", "]") for page in pages_section], IE_query=IE_query, output_data_structure=Article)
#       3 semantic_blocks = [f"{key} - {value}".replace("{", "[").replace("}", "]")
#       4                      for key, value in facts_0.model_dump().items()
#       5                      if value != [] and value != "" and value is not None]
#
# File ~\anaconda3\Lib\site-packages\itext2kg\documents_distiller\documents_distiller.py:190, in DocumentsDistiller.distill(self, documents, output_data_structure, IE_query)
#     177 """
#     178 Distill information from multiple documents based on a specific information extraction query.
#     179
#    (...)
#     187                        Returns the same type as the objects returned by the language model.
#     188 """
#     189 # Use the batch processing capability of the async method
# --> 190 output_jsons = await self.langchain_output_parser.extract_information_as_json_for_context(
#     191     contexts=documents,
#     192     system_query=IE_query,
#     193     output_data_structure=output_data_structure
#     194 )
#     196 return DocumentsDistiller.__combine_objects(output_jsons)
#
# File ~\anaconda3\Lib\site-packages\itext2kg\llm_output_parsing\langchain_output_parser.py:105, in LangchainOutputParser.extract_information_as_json_for_context(self, output_data_structure, contexts, system_query)
#     103 for batch in batches:
#     104     try:
# --> 105         batch_outputs = await structured_llm.abatch(batch)
#     106         outputs.extend(batch_outputs)
#     107     except openai.BadRequestError as e:
#
# File ~\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:3328, in RunnableSequence.abatch(self, inputs, config, return_exceptions, **kwargs)
#    3326     else:
#    3327         for i, step in enumerate(self.steps):
# -> 3328             inputs = await step.abatch(
#    3329                 inputs,
#    3330                 [
#    3331                     # each step a child run of the corresponding root run
#    3332                     patch_config(
#    3333                         config, callbacks=rm.get_child(f"seq:step:{i + 1}")
#    3334                     )
#    3335                     for rm, config in zip(run_managers, configs)
#    3336                 ],
#    3337                 return_exceptions=return_exceptions,
#    3338                 **(kwargs if i == 0 else {}),
#    3339             )
#    3340 # finish the root runs
#    3341 except BaseException as e:
#
# File ~\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:5492, in RunnableBindingBase.abatch(self, inputs, config, return_exceptions, **kwargs)
#    5490 else:
#    5491     configs = [self._merge_configs(config) for _ in range(len(inputs))]
# -> 5492 return await self.bound.abatch(
#    5493     inputs,
#    5494     configs,
#    5495     return_exceptions=return_exceptions,
#    5496     **{**self.kwargs, **kwargs},
#    5497 )
#
# File ~\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:916, in Runnable.abatch(self, inputs, config, return_exceptions, **kwargs)
#     913         return await self.ainvoke(value, config, **kwargs)
#     915 coros = map(ainvoke, inputs, configs)
# --> 916 return await gather_with_concurrency(configs[0].get("max_concurrency"), *coros)
#
# File ~\anaconda3\Lib\site-packages\langchain_core\runnables\utils.py:71, in gather_with_concurrency(n, *coros)
#      61 """Gather coroutines with a limit on the number of concurrent coroutines.
#      62
#      63 Args:
#    (...)
#      68     The results of the coroutines.
#      69 """
#      70 if n is None:
# ---> 71     return await asyncio.gather(*coros)
#      73 semaphore = asyncio.Semaphore(n)
#      75 return await asyncio.gather(*(gated_coro(semaphore, c) for c in coros))
#
# File ~\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:913, in Runnable.abatch.<locals>.ainvoke(value, config)
#     911         return e
#     912 else:
# --> 913     return await self.ainvoke(value, config, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:417, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     407 @override
#     408 async def ainvoke(
#     409     self,
#    (...)
#     414     **kwargs: Any,
#     415 ) -> BaseMessage:
#     416     config = ensure_config(config)
# --> 417     llm_result = await self.agenerate_prompt(
#     418         [self._convert_input(input)],
#     419         stop=stop,
#     420         callbacks=config.get("callbacks"),
#     421         tags=config.get("tags"),
#     422         metadata=config.get("metadata"),
#     423         run_name=config.get("run_name"),
#     424         run_id=config.pop("run_id", None),
#     425         **kwargs,
#     426     )
#     427     return cast("ChatGeneration", llm_result.generations[0][0]).message
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:991, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#     982 @override
#     983 async def agenerate_prompt(
#     984     self,
#    (...)
#     988     **kwargs: Any,
#     989 ) -> LLMResult:
#     990     prompt_messages = [p.to_messages() for p in prompts]
# --> 991     return await self.agenerate(
#     992         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#     993     )
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:911, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     898 run_managers = await callback_manager.on_chat_model_start(
#     899     self._serialized,
#     900     messages_to_trace,
#    (...)
#     905     run_id=run_id,
#     906 )
#     908 input_messages = [
#     909     _normalize_messages(message_list) for message_list in messages
#     910 ]
# --> 911 results = await asyncio.gather(
#     912     *[
#     913         self._agenerate_with_cache(
#     914             m,
#     915             stop=stop,
#     916             run_manager=run_managers[i] if run_managers else None,
#     917             **kwargs,
#     918         )
#     919         for i, m in enumerate(input_messages)
#     920     ],
#     921     return_exceptions=True,
#     922 )
#     923 exceptions = []
#     924 for i, res in enumerate(results):
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1115     result = generate_from_stream(iter(chunks))
#    1116 elif inspect.signature(self._agenerate).parameters.get("run_manager"):
# -> 1117     result = await self._agenerate(
#    1118         messages, stop=stop, run_manager=run_manager, **kwargs
#    1119     )
#    1120 else:
#    1121     result = await self._agenerate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain_ollama\chat_models.py:993, in ChatOllama._agenerate(self, messages, stop, run_manager, **kwargs)
#     986 async def _agenerate(
#     987     self,
#     988     messages: list[BaseMessage],
#    (...)
#     991     **kwargs: Any,
#     992 ) -> ChatResult:
# --> 993     final_chunk = await self._achat_stream_with_aggregation(
#     994         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     995     )
#     996     generation_info = final_chunk.generation_info
#     997     chat_generation = ChatGeneration(
#     998         message=AIMessage(
#     999             content=final_chunk.text,
#    (...)
#    1004         generation_info=generation_info,
#    1005     )
#
# File ~\anaconda3\Lib\site-packages\langchain_ollama\chat_models.py:780, in ChatOllama._achat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     771 async def _achat_stream_with_aggregation(
#     772     self,
#     773     messages: list[BaseMessage],
#    (...)
#     777     **kwargs: Any,
#     778 ) -> ChatGenerationChunk:
#     779     final_chunk = None
# --> 780     async for chunk in self._aiterate_over_stream(messages, stop, **kwargs):
#     781         if final_chunk is None:
#     782             final_chunk = chunk
#
# File ~\anaconda3\Lib\site-packages\langchain_ollama\chat_models.py:917, in ChatOllama._aiterate_over_stream(self, messages, stop, **kwargs)
#     910 async def _aiterate_over_stream(
#     911     self,
#     912     messages: list[BaseMessage],
#     913     stop: Optional[list[str]] = None,
#     914     **kwargs: Any,
#     915 ) -> AsyncIterator[ChatGenerationChunk]:
#     916     reasoning = kwargs.get("reasoning", self.reasoning)
# --> 917     async for stream_resp in self._acreate_chat_stream(messages, stop, **kwargs):
#     918         if not isinstance(stream_resp, str):
#     919             content = (
#     920                 stream_resp["message"]["content"]
#     921                 if "message" in stream_resp and "content" in stream_resp["message"]
#     922                 else ""
#     923             )
#
# File ~\anaconda3\Lib\site-packages\langchain_ollama\chat_models.py:725, in ChatOllama._acreate_chat_stream(self, messages, stop, **kwargs)
#     722 chat_params = self._chat_params(messages, stop, **kwargs)
#     724 if chat_params["stream"]:
# --> 725     async for part in await self._async_client.chat(**chat_params):
#     726         yield part
#     727 else:
#
# File ~\anaconda3\Lib\site-packages\ollama\_client.py:677, in AsyncClient._request.<locals>.inner()
#     676 async def inner():
# --> 677   async with self._client.stream(*args, **kwargs) as r:
#     678     try:
#     679       r.raise_for_status()
#
# File ~\anaconda3\Lib\contextlib.py:210, in _AsyncGeneratorContextManager.__aenter__(self)
#     208 del self.args, self.kwds, self.func
#     209 try:
# --> 210     return await anext(self.gen)
#     211 except StopAsyncIteration:
#     212     raise RuntimeError("generator didn't yield") from None
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:1617, in AsyncClient.stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1594 """
#    1595 Alternative to `httpx.request()` that streams the response body
#    1596 instead of loading it into memory at once.
#    (...)
#    1602 [0]: /quickstart#streaming-responses
#    1603 """
#    1604 request = self.build_request(
#    1605     method=method,
#    1606     url=url,
#    (...)
#    1615     extensions=extensions,
#    1616 )
# -> 1617 response = await self.send(
#    1618     request=request,
#    1619     auth=auth,
#    1620     follow_redirects=follow_redirects,
#    1621     stream=True,
#    1622 )
#    1623 try:
#    1624     yield response
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:1661, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1653 follow_redirects = (
#    1654     self.follow_redirects
#    1655     if isinstance(follow_redirects, UseClientDefault)
#    1656     else follow_redirects
#    1657 )
#    1659 auth = self._build_request_auth(request, auth)
# -> 1661 response = await self._send_handling_auth(
#    1662     request,
#    1663     auth=auth,
#    1664     follow_redirects=follow_redirects,
#    1665     history=[],
#    1666 )
#    1667 try:
#    1668     if not stream:
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:1689, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1686 request = await auth_flow.__anext__()
#    1688 while True:
# -> 1689     response = await self._send_handling_redirects(
#    1690         request,
#    1691         follow_redirects=follow_redirects,
#    1692         history=history,
#    1693     )
#    1694     try:
#    1695         try:
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:1726, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1723 for hook in self._event_hooks["request"]:
#    1724     await hook(request)
# -> 1726 response = await self._send_single_request(request)
#    1727 try:
#    1728     for hook in self._event_hooks["response"]:
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:1763, in AsyncClient._send_single_request(self, request)
#    1758     raise RuntimeError(
#    1759         "Attempted to send an sync request with an AsyncClient instance."
#    1760     )
#    1762 with request_context(request=request):
# -> 1763     response = await transport.handle_async_request(request)
#    1765 assert isinstance(response.stream, AsyncByteStream)
#    1766 response.request = request
#
# File ~\anaconda3\Lib\site-packages\httpx\_transports\default.py:373, in AsyncHTTPTransport.handle_async_request(self, request)
#     360 req = httpcore.Request(
#     361     method=request.method,
#     362     url=httpcore.URL(
#    (...)
#     370     extensions=request.extensions,
#     371 )
#     372 with map_httpcore_exceptions():
# --> 373     resp = await self._pool.handle_async_request(req)
#     375 assert isinstance(resp.stream, typing.AsyncIterable)
#     377 return Response(
#     378     status_code=resp.status,
#     379     headers=resp.headers,
#     380     stream=AsyncResponseStream(resp.stream),
#     381     extensions=resp.extensions,
#     382 )
#
# File ~\anaconda3\Lib\site-packages\httpcore\_async\connection_pool.py:268, in AsyncConnectionPool.handle_async_request(self, request)
#     266     with AsyncShieldCancellation():
#     267         await self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~\anaconda3\Lib\site-packages\httpcore\_async\connection_pool.py:251, in AsyncConnectionPool.handle_async_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = await connection.handle_async_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     async with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~\anaconda3\Lib\site-packages\httpcore\_async\connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return await self._connection.handle_async_request(request)
#
# File ~\anaconda3\Lib\site-packages\httpcore\_async\http11.py:133, in AsyncHTTP11Connection.handle_async_request(self, request)
#     131     async with Trace("response_closed", logger, request) as trace:
#     132         await self._response_closed()
# --> 133 raise exc
#
# File ~\anaconda3\Lib\site-packages\httpcore\_async\http11.py:111, in AsyncHTTP11Connection.handle_async_request(self, request)
#     101     pass
#     103 async with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = await self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~\anaconda3\Lib\site-packages\httpcore\_async\http11.py:176, in AsyncHTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = await self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~\anaconda3\Lib\site-packages\httpcore\_async\http11.py:212, in AsyncHTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = await self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\anaconda3\Lib\site-packages\httpcore\_backends\anyio.py:34, in AnyIOStream.read(self, max_bytes, timeout)
#      32 with anyio.fail_after(timeout):
#      33     try:
# ---> 34         return await self._stream.receive(max_bytes=max_bytes)
#      35     except anyio.EndOfStream:  # pragma: nocover
#      36         return b""
#
# File ~\anaconda3\Lib\site-packages\anyio\_backends\_asyncio.py:1123, in SocketStream.receive(self, max_bytes)
#    1118 if (
#    1119     not self._protocol.read_event.is_set()
#    1120     and not self._transport.is_closing()
#    1121 ):
#    1122     self._transport.resume_reading()
# -> 1123     await self._protocol.read_event.wait()
#    1124     self._transport.pause_reading()
#    1126 try:
#
# File ~\anaconda3\Lib\asyncio\locks.py:212, in Event.wait(self)
#     210 self._waiters.append(fut)
#     211 try:
# --> 212     await fut
#     213     return True
#     214 finally:
#
# CancelledError:
